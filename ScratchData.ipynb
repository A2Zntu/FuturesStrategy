# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd
import os
import numpy as np
import time
import re
import warnings
import json 
import datetime as dt
import argparse
warnings.filterwarnings('ignore')

# %%
def get_futures_after_hours_data(date): 
    res = requests.get()

# %%
webpage = 'https://www.taifex.com.tw/cht/3/futContractsDate' 
res = requests.get(webpage)
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <html lang="zh-TW" xmlns="http://www.w3.org/1999/xhtml">
# <head><meta content="IE=edge" http-equiv="X-UA-Compatible"/></head><!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/cht/resources/front/cht/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="https://www.taifex.com.tw/chinese/images/fb_logo.jpg" property="og:image">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>交易資訊/三大法人/查詢/區分各期貨契約/依日期</title>
# <link href="/cht/resources/front/cht/css/global.css" rel="stylesheet" type="text/css"/>
# <link href="/cht/resources/front/cht/css/content.css" rel="stylesheet" type="text/css"/>
# <link href="/cht/resources/front/cht/css/index.css" rel="stylesheet" type="text/css"/>
# ...

# %%
tables = soup.find_all("table", {'class': 'table_f'})
print(len(tables))
# Out:
# 1

# %%
columns = []
for line in tables:
    for row in line.find_all('tr'):
         for th in line.find_all('th'): 
            columns.append(th)

# %%
col
# Out:
# [   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 交易口數與契約金額  \
#     Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1        多方
#                     序號               商品名稱                身份別        口數
#  0                   1               臺股期貨                自營商     12142
#  1                   1               臺股期貨                 投信       473
#  2                   1               臺股期貨                 外資     83183
#  3                   2               電子期貨                自營商       466
#  4                   2               電子期貨                 投信         1
#  5                   2               電子期貨                 外資      1518
#  6                   3               金融期貨                自營商        95
#  7                   3               金融期貨                 投信         0
#  8                   3               金融期貨                 外資       428
#  9                   4             小型臺指期貨                自營商     11400
# ...
